# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Instalación:

# %%
pip install matplotlib

# %%
import matplotlib as plt

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Plot

# %%
import numpy as np
puntos_x = np.array([0, 4, 8, 16])
puntos_y = np.array([6, 12, 24, 48])
plt.plot(puntos_x, puntos_y)
plt.show()

# %%
x1= np.array([0, 1, 2, 3])
y1= np.array([3, 8, 1, 10])
x2= np.array ([0, 1, 2, 3])
y2= np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# #### Formato

# %% [markdown]
# Diagrama de puntos:

# %%
puntos_y = np.array([6, 12, 24, 48])
plt.plot(puntos_y, 'o')
plt.show()

# %% [markdown]
# Argumentos:

# %% [markdown]
# Modificar estilo de línea: <br>
# <br>
# '-' <br>
# ':' <br>
# '--' <br>
# '-.' <br>

# %% [markdown]
# Color: <br>
# <br>
# 'r'<br>
# etc...

# %% [markdown]
# Tanaño: <br>
# <br>
# 'o--k': punto con doble línea en color negro <br>
# ms: tamaño de los marcadores <br>
# mec='r': contorno rojo <br>

# %%
plt.plot(puntos_x, puntos_y, 'o--k', ms=16, mec= 'r', linewidth= '16')

# %% [markdown]
# Títulos<br>
# plt.title, plt.xlabel y plt.ylabel:

# %%
x=np.array([80, 85, 95, 100, 105, 110, 115, 120, 125])
y=np.array([240, 250, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("Estadísticas deportivas")
plt.xlabel("Pulso Promedio")
plt.ylabel("Quema de calorías")
plt.show()

# %% [markdown]
# Personalización de los títulos:

# %%
plt.plot(x, y)
font1= {'family':'serif', 'color':'blue', 'size':20}
font2= {'family':'serif', 'color'............etc}

# %% [markdown]
# Ubicación de los textos:

# %% [markdown]
# #### Grid

# %% [markdown]
# Agrega un fondo cuadriculado o personalizado

# %%
x= np.array([80, 85, 90, 95])
y= np.array([240, 259, 260, 270])
plt.grid(axis= 'x', linestyle= '--', linewidth =1)
